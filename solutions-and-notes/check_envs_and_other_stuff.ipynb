# %% [markdown]
# # *Remember to clear all cell output before commiting to git*
#
# !!**BEAWARE**!!

# %%
import os
print(os.environ['OPEN_API_KEY'])

# %% [markdown]
# The next step if you are using langchain studio - only works on Mac af of writing this

# %%
# %%bash
# for i in {1..4}; do
# cp ../module-$i/studio/.env.example ../module-$i/studio/.env
# echo "OPENAI_API_KEY=\"<YOUR KEY>\"" > ../module-$i/studio/.env
# done
